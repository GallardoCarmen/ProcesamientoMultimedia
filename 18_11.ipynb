# %% [markdown]
# <a href="https://colab.research.google.com/github/GallardoCarmen/ProcesamientoMultimedia/blob/main/18_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr
# !pip install pytesseract
# !pip install imutils
# !sudo apt install tesseract-ocr

# !pip install opencv-python
# !pip install opencv_jupyter_ui
# !pip install -q ipycanvas==0.11
from google.colab import output
output.enable_custom_widget_manager()

import cv2
from google.colab.patches import cv2_imshow
import opencv_jupyter_ui as jcv2



# !sudo apt install tesseract-ocr
# !pip install pytessseract
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ERROR: Could not find a version that satisfies the requirement pytessseract (from versions: none)
# ERROR: No matching distribution found for pytessseract

# %%
image = cv2.imread("car.jpeg")

#reduciendo detalles
image = cv2.resize(image,(500,500));

jcv2.imshow("car",image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

gray = cv2.blur(gray, (6,6))

gray_d = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)
jcv2.imshow("blur",gray_d)


edge = cv2.Canny(gray, 20, 200)


edge_d = cv2.cvtColor(edge, cv2.COLOR_GRAY2BGR)
jcv2.imshow("edge",edge_d)


contours, _ = cv2.findContours(edge, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE);

for c in contours:
  area = cv2.contourArea(c)
  #print(area)
  image1 = image;
  cv2.drawContours(image1, [c], -1, (0, 255, 0), 3);
  perimetro = cv2.arcLength(c,True)
  vertice = cv2.approxPolyDP(c, 0.02 * perimetro, True)
  if (len(vertice) == 4):
    print("palte detected")
    #x,y,h,w = cv2.boundingRect(c);
    #cv2.rectangle(image, (x,y), (x+w,y+h),(0,0,255),3)
    jcv2.imshow("car",image)

    plate = image[y:y+h,x:x+h];
    jcv2.imshow("plate", plate);
# Out:
# ...
# palte detected
# ...
# palte detected
# palte detected
# palte detected
# palte detected
